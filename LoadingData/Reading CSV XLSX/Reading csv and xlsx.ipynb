# %%
import pandas as pd

# %%
df = pd.read_csv('username.csv')

# %%
df
# Out:
#     Username  Identifier First name Last name
# 0   booker12        9012     Rachel    Booker
# 1     grey07        2070      Laura      Grey
# 2  johnson81        4081      Craig   Johnson
# 3  jenkins46        9346       Mary   Jenkins
# 4    smith79        5079      Jamie     Smith

# %%
df = pd.read_csv('exlcsv.csv')

# %%
df
# Out:
#      Name  Age    City
# 0  Name 1   25   Blore
# 1  Name 2   22  Mumbai
# 2  Name 3   33   Delhi

# %%
df = pd.read_excel('exlwb.xlsx', engine='openpyxl')

# %%
df
# Out:
#      Name  Age    City
# 0  Name 1   25   Blore
# 1  Name 2   22  Mumbai
# 2  Name 3   33   Delhi

# %%
df = pd.read_excel('exlprops.xlsx', engine='openpyxl')

# %%
df.head()
# Out:
#    NHPDPropertyID                      PropertyName    PropertyAddress  \
# 0         1000000                       IVY ESTATES  6729 Zeigler Blvd
# 1         1000001                RENDU TERRACE WEST  7400 Old Shell Rd
# 2         1000002  TWB RESIDENTIAL OPPORTUNITIES II        93 Canal Rd
# 3         1000003                   THE DAISY HOUSE    615 Clarissa St
# 4         1000004            MAIN AVENUE APARTMENTS    105 E Walnut St
#
#                      City State         Zip  CBSACode  \
# 0                  Mobile    AL  36608-4253   33660.0
# 1                  Mobile    AL  36608-4549   33660.0
# 2  Port Jefferson Station    NY  11776-3024   35620.0
# 3               Rochester    NY  14608-2485   40380.0
# 4               Sylacauga    AL  35150-3012   45180.0
#
#                         CBSAType     County  CountyCode  ...  NumberActiveMR  \
# 0  Metropolitan Statistical Area     Mobile      1097.0  ...               0
# ...

# %%
# During the datadive event, you were unable to load the .xlsx file you'd converted to .csv because
# the default encoding was unable to process the start of some bytes.
# The below suggestion from stackoverflow helped.
# Standard encodings: https://docs.python.org/3/library/codecs.html#standard-encodings 

df_csv = pd.read_csv('csvprops.csv', encoding = 'unicode_escape', engine ='python')
df_csv.head()
# Out:
#    NHPDPropertyID                      PropertyName    PropertyAddress  \
# 0         1000000                       IVY ESTATES  6729 Zeigler Blvd
# 1         1000001                RENDU TERRACE WEST  7400 Old Shell Rd
# 2         1000002  TWB RESIDENTIAL OPPORTUNITIES II        93 Canal Rd
# 3         1000003                   THE DAISY HOUSE    615 Clarissa St
# 4         1000004            MAIN AVENUE APARTMENTS    105 E Walnut St
#
#                      City State         Zip  CBSACode  \
# 0                  Mobile    AL  36608-4253   33660.0
# 1                  Mobile    AL  36608-4549   33660.0
# 2  Port Jefferson Station    NY  11776-3024   35620.0
# 3               Rochester    NY  14608-2485   40380.0
# 4               Sylacauga    AL  35150-3012   45180.0
#
#                         CBSAType     County  CountyCode  ...  NumberActiveMR  \
# 0  Metropolitan Statistical Area     Mobile      1097.0  ...               0
# ...

# %%
# Out:
#     Name  year  age
# 0  'foo'    23   67
# 1    bar    23   90
